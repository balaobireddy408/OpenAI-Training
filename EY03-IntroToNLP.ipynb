# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# 3 most popular libraries-> NLTK, Spacy, Textacy 

import spacy

# %%
dictionary = spacy.load('en_core_web_sm')

# %%
text = """Mary had a little lamb, and little lamb said 'bye bye i am going home'. 
This sounds very strange, because lamb was planning to go on a dinner with the goat. 
Lamb started watching a movie and absolutely hated it."""

# %%
# Document -> pages -> paragraphs 
# SENTENCES -> WORDS -> TOKENS
# MULTIPLE  worlds can also form a token-> 'The Himalayas', 'didn't'

nlp = dictionary(text)
print(dir(nlp))
# Out:
# ['_', '__bytes__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '_bulk_merge', '_py_tokens', '_realloc', '_vector', '_vector_norm', 'cats', 'char_span', 'count_by', 'doc', 'ents', 'extend_tensor', 'from_array', 'from_bytes', 'from_disk', 'get_extension', 'get_lca_matrix', 'has_extension', 'has_vector', 'is_nered', 'is_parsed', 'is_sentenced', 'is_tagged', 'lang', 'lang_', 'mem', 'merge', 'noun_chunks', 'noun_chunks_iterator', 'print_tree', 'remove_extension', 'retokenize', 'sentiment', 'sents', 'set_extension', 'similarity', 'tensor', 'text', 'text_with_ws', 'to_array', 'to_bytes', 'to_disk', 'to_json', 'to_utf8_array', 'user_data', 'user_hooks'
# ...

# %%
nlp.vector
# Out:
# array([ 0.24758364,  0.5431671 , -0.2713072 , -0.28868946,  1.2571356 ,
#        -0.15770252,  0.8608815 ,  0.17428099,  1.0962297 ,  0.96357244,
#        -0.46640193, -0.41103148,  0.44320568, -0.21468838, -0.5234426 ,
#        -0.13964511, -0.47593307,  0.15300126, -0.88984245, -0.7472464 ,
#         0.20619814, -0.13152522, -0.36166015, -0.30678073, -0.37689948,
#         0.65342075, -0.39846203, -0.34144756,  0.57948476, -0.7906257 ,
#         0.54746825,  0.2816256 ,  0.23126271, -0.19099204,  0.733105  ,
#        -0.5867983 ,  0.18069333, -1.4143114 , -1.3879019 , -0.55082804,
#         0.71436214,  0.12765732,  0.02156684, -0.60639733,  0.20048472,
#         0.3119735 , -0.02814709, -0.12920602, -0.51340634,  0.8442266 ,
#         0.51966137, -0.6950353 , -0.29984218, -0.14412525, -1.1954775 ,
#         0.42467207,  1.0423796 ,  0.646033  ,  0.3908897 ,  0.49047035,
#         1.1022044 , -0.50397325,  0.6320795 ,  0.14056014,  0.8596669 ,
# ...

# %%
# tokens inside the sentences 
for i in range(len(nlp)):
    print(' [ ' + str(nlp[i]), end=' ], ')
# Out:
#  [ Mary ],  [ had ],  [ a ],  [ little ],  [ lamb ],  [ , ],  [ and ],  [ little ],  [ lamb ],  [ said ],  [ ' ],  [ bye ],  [ bye ],  [ i ],  [ am ],  [ going ],  [ home ],  [ ' ],  [ . ],  [
#  ],  [ This ],  [ sounds ],  [ very ],  [ strange ],  [ , ],  [ because ],  [ lamb ],  [ was ],  [ planning ],  [ to ],  [ go ],  [ on ],  [ a ],  [ dinner ],  [ with ],  [ the ],  [ goat ],  [ . ],  [
#  ],  [ Lamb ],  [ started ],  [ watching ],  [ a ],  [ movie ],  [ and ],  [ absolutely ],  [ hated ],  [ it ],  [ . ],

# %%
for i in range(len(nlp)):
    print(nlp[i], end=' = ')
    print(nlp[i].vector)
# Out:
# Mary = [-1.4509495  -1.5681124  -1.9461675   1.839561    3.4780774   2.524608
#   0.33326906 -1.5484917   7.4678564   0.60519946  3.1377375   0.7935887
#   0.58354187 -0.2661229  -2.226547    0.1650516   0.19616508  0.44295195
#  -0.6433928  -1.1714629  -1.6007192  -2.0752583   0.25768483 -3.8029935
#  -1.9360929   0.03117523 -3.39713    -3.5714767  -0.60103    -0.9838464
#   2.1978376  -3.2238326  -0.32594115  0.8433224   7.957924   -0.03823709
#  -0.24748272 -1.4541488  -1.1449388   0.5361395   0.31154394 -1.2105138
#   3.0802765  -2.5341787  -0.34331483  2.37043    -1.4925265  -0.588382
#  -0.01588336  6.6166472  -2.1355598  -1.0340636  -2.2041569   0.04030764
#  -5.109659    2.916152    1.064828    1.0461608   2.3962123  -2.4949212
#  -2.0643337  -0.4496295  -1.3907826  -1.2317047   1.3493019   1.4107083
#  -1.2005286  -2.8885674  -1.2789047   0.61199975 -0.8376126   3.2062962
#  -2.1587226   1.1197324   0.09724939 -3.640162    1.962763    0.34758192
# ...

# %%
for i in range(len(nlp)):
    print('Grammar')
    print(nlp[i], end=' is a ')
    print(nlp[i].pos_)
    print('Tag = ', end = '')
    print(nlp[i].tag_)
# Out:
# Grammar
# Mary is a PROPN
# Tag = NNP
# Grammar
# had is a AUX
# Tag = VBD
# Grammar
# a is a DET
# Tag = DT
# Grammar
# little is a ADJ
# Tag = JJ
# Grammar
# lamb is a NOUN
# Tag = NN
# Grammar
# , is a PUNCT
# Tag = ,
# Grammar
# and is a CCONJ
# Tag = CC
# Grammar
# little is a ADJ
# Tag = JJ
# Grammar
# lamb is a NOUN
# Tag = NN
# Grammar
# said is a VERB
# Tag = VBD
# Grammar
# ' is a PUNCT
# Tag = ''
# Grammar
# bye is a INTJ
# Tag = UH
# Grammar
# bye is a INTJ
# Tag = UH
# Grammar
# i is a PRON
# Tag = PRP
# Grammar
# am is a AUX
# Tag = VBP
# Grammar
# going is a VERB
# Tag = VBG
# Grammar
# home is a ADV
# Tag = RB
# Grammar
# ' is a PUNCT
# Tag = ''
# Grammar
# . is a PUNCT
# Tag = .
# Grammar
#
#  is a SPACE
# Tag = _SP
# Grammar
# This is a DET
# Tag = DT
# Grammar
# sounds is a VERB
# Tag = VBZ
# Grammar
# very is a ADV
# Tag = RB
# Grammar
# strange is a ADJ
# Tag = JJ
# Grammar
# , is a PUNCT
# Tag = ,
# Grammar
# because is a SCONJ
# Tag = IN
# Grammar
# ...

# %%
# Objective = collect all nouns from the data 
all_nouns = []
for i in range ( len (nlp)):
    if(nlp[i].pos_ == 'NOUN' or nlp[i].pos_=='PROPN'):
        all_nouns.append(nlp[i])

# %%
all_nouns
# Out:
# [Mary, lamb, lamb, lamb, dinner, goat, Lamb, movie]

# %%
set(all_nouns) # here the set shows repeated elements-> because we aren't dealing with strings, but individual TOKENS
# Out:
# {Mary, lamb, lamb, lamb, dinner, goat, Lamb, movie}

# %%
# Objective = collect all nouns from the data 
all_nouns = []
for i in range ( len (nlp)):
    if(nlp[i].pos_ == 'NOUN' or nlp[i].pos_=='PROPN'):
        all_nouns.append(str(nlp[i]).lower())

# %%
# unique nouns 
all_nouns_unique = set(all_nouns)

# %%
all_nouns_unique # now that we have type casted into str, only unique strings are displayed!
# Out:
# {'dinner', 'goat', 'lamb', 'mary', 'movie'}

# %%
# comparing the state, sentiment, trying to summarize, intentions

# words can be represented in many ways:
# studied, studies, study, studying 

# reduce the words into their minial form 

# Lemmatization and Stemming 

# Stemming reduces the word according to their greek and latin and viking.... structures 
# Lemmatization's result is from english dictionary

# %%
print(dir(nlp[0]))
# Out:
# ['_', '__bytes__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', 'ancestors', 'check_flag', 'children', 'cluster', 'conjuncts', 'dep', 'dep_', 'doc', 'ent_id', 'ent_id_', 'ent_iob', 'ent_iob_', 'ent_kb_id', 'ent_kb_id_', 'ent_type', 'ent_type_', 'get_extension', 'has_extension', 'has_vector', 'head', 'i', 'idx', 'is_alpha', 'is_ancestor', 'is_ascii', 'is_bracket', 'is_currency', 'is_digit', 'is_left_punct', 'is_lower', 'is_oov', 'is_punct', 'is_quote', 'is_right_punct', 'is_sent_start', 'is_space', 'is_stop', 'is_title', 'is_upper', 'lang', 'lang_', 'left_edge', 'lefts', 'lemma', 'lemma_', 'lex_id', 'like_email', 'like_num', 'like_url', 'lower', 'lower_', 'morph', 'n_lefts', 'n_rights', '
# ...

# %%
all_lemms = []
for i ina range(len(nlp)):
    print(nlp[i] , end = ' = ')
    print(nlp[i].lemma_)
    all_lemms.append(nlp[i].lemma_)
# Out:
# Mary = Mary
# had = have
# a = a
# little = little
# lamb = lamb
# , = ,
# and = and
# little = little
# lamb = lamb
# said = say
# ' = '
# bye = bye
# bye = bye
# i = i
# am = be
# going = go
# home = home
# ' = '
# . = .
#
#  =
#
# This = this
# sounds = sound
# very = very
# strange = strange
# , = ,
# because = because
# lamb = lamb
# was = be
# planning = plan
# to = to
# go = go
# on = on
# a = a
# dinner = dinner
# with = with
# the = the
# goat = goat
# . = .
#
#  =
#
# Lamb = Lamb
# started = start
# watching = watch
# a = a
# movie = movie
# and = and
# absolutely = absolutely
# hated = hate
# it = -PRON-
# . = .

# %%
print(all_lemms)
# Out:
# ['Mary', 'have', 'a', 'little', 'lamb', ',', 'and', 'little', 'lamb', 'say', "'", 'bye', 'bye', 'i', 'be', 'go', 'home', "'", '.', '\n', 'this', 'sound', 'very', 'strange', ',', 'because', 'lamb', 'be', 'plan', 'to', 'go', 'on', 'a', 'dinner', 'with', 'the', 'goat', '.', '\n', 'Lamb', 'start', 'watch', 'a', 'movie', 'and', 'absolutely', 'hate', '-PRON-', '.']

# %%
# 10,000 product reviews
# nouns -> per review-> which product-> 10k + nouns
# unique products -> set()

# %%
print(dir(nlp[0]))
# Out:
# ['_', '__bytes__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', 'ancestors', 'check_flag', 'children', 'cluster', 'conjuncts', 'dep', 'dep_', 'doc', 'ent_id', 'ent_id_', 'ent_iob', 'ent_iob_', 'ent_kb_id', 'ent_kb_id_', 'ent_type', 'ent_type_', 'get_extension', 'has_extension', 'has_vector', 'head', 'i', 'idx', 'is_alpha', 'is_ancestor', 'is_ascii', 'is_bracket', 'is_currency', 'is_digit', 'is_left_punct', 'is_lower', 'is_oov', 'is_punct', 'is_quote', 'is_right_punct', 'is_sent_start', 'is_space', 'is_stop', 'is_title', 'is_upper', 'lang', 'lang_', 'left_edge', 'lefts', 'lemma', 'lemma_', 'lex_id', 'like_email', 'like_num', 'like_url', 'lower', 'lower_', 'morph', 'n_lefts', 'n_rights', '
# ...

# %%
nlp[0].is_stop
# Out:
# False

# %%
# stop words-> USELESS WORDS that make no contribution whatsoever! 
clean_dict = []
for i in range(len(nlp)):
    if(nlp[i].is_stop == False):
        clean_dict.append(nlp[i].text)
print(clean_dict)
# Out:
# ['Mary', 'little', 'lamb', ',', 'little', 'lamb', 'said', "'", 'bye', 'bye', 'going', 'home', "'", '.', '\n', 'sounds', 'strange', ',', 'lamb', 'planning', 'dinner', 'goat', '.', '\n', 'Lamb', 'started', 'watching', 'movie', 'absolutely', 'hated', '.']

# %%
len(clean_dict), len(nlp)
# Out:
# (31, 49)

# %%
print(" ".join(clean_dict))
# Out:
# Mary little lamb , little lamb said ' bye bye going home ' .
#  sounds strange , lamb planning dinner goat .
#  Lamb started watching movie absolutely hated .

# %%
print(text) #reduced size = better and cheaper communication, easier load on ram, lower network congestion!
# Out:
# Mary had a little lamb, and little lamb said 'bye bye i am going home'.
# This sounds very strange, because lamb was planning to go on a dinner with the goat.
# Lamb started watching a movie and absolutely hated it.
