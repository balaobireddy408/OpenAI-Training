# %% [markdown]
# <a href="https://colab.research.google.com/github/balaobireddy408/OpenAI-Training/blob/main/EY05_TextAnalysisRegex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [a-zA-Z]{3}[ ]?[0-9]{4} -> 3 letters of any case, followed by 1 space (optional), followed by 4 nums!
# ?      means 0 or 1 occurance
# +      means 1 or more occurance
# *      means 0 or more occurance
# ^      means start of the pattern
# $      means end of the pattern

# %%
pattern = '£ ?[0-9][0-9]?' # £ then SPACE-optional then digit then digit-optional

document = 'My eggs cost £ 3, bread cost £2, vodka cost £ 35'

# %%
import re

# %%
re.findall(pattern, document)
# Out:
# ['£ 3', '£2', '£ 35']

# %%
import pandas as pd

# %%
ti = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/diamler_17_jan/main/titanic.csv')
ti.sample(2)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 299         1       1  female  50.0      0      1  247.5208        C  First
# 773         0       3    male   NaN      0      0    7.2250        C  Third
#
#        who  adult_male deck embark_town alive  alone
# 299  woman       False    B   Cherbourg   yes  False
# 773    man        True  NaN   Cherbourg    no   True

# %%
ti['ticket'] = "Ticket: " + ti['class'] + "; Price: $ " + ti['fare'].astype(str) + "; Port: " + ti['embark_town'] + ";"

# %%
ti[['class', 'fare', 'embark_town', 'ticket']].head(3)
# Out:
#    class     fare  embark_town  \
# 0  Third   7.2500  Southampton
# 1  First  71.2833    Cherbourg
# 2  Third   7.9250  Southampton
#
#                                               ticket
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;

# %%
pattern = '(First|Second)'

ti['class'].str.match(pattern)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890    False
# Name: class, Length: 891, dtype: bool

# %%
ti.loc[ ti['class'].str.match(pattern)  , 'survived'].mean()
# Out:
# 0.5575

# %%
pattern = '(Third)'
ti.loc[ ti['class'].str.match(pattern)  , 'survived'].mean()
# Out:
# 0.24236252545824846

# %%
ti[['class', 'fare', 'embark_town', 'ticket']].head(3)
# Out:
#    class     fare  embark_town  \
# 0  Third   7.2500  Southampton
# 1  First  71.2833    Cherbourg
# 2  Third   7.9250  Southampton
#
#                                               ticket
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;

# %%
#just for demo, no real purpose
pattern = '([0-9.]+)'

ti['ticket'].str.extract(pattern).sample(4)
# Out:
#             0
# 269  135.6333
# 324     69.55
# 173     7.925
# 687   10.1708

# %%
ti['ticket'].str.replace('$', '€').sample(1)
# Out:
# 689    Ticket: First; Price: € 211.3375; Port: Southa...
# Name: ticket, dtype: object

# %%
ti['ticket'].str.extract('(Ticket: (First|Second))')
# Out:
#                   0       1
# 0               NaN     NaN
# 1     Ticket: First   First
# 2               NaN     NaN
# 3     Ticket: First   First
# 4               NaN     NaN
# ..              ...     ...
# 886  Ticket: Second  Second
# 887   Ticket: First   First
# 888             NaN     NaN
# 889   Ticket: First   First
# 890             NaN     NaN
#
# [891 rows x 2 columns]

# %%
ti['ticket'].str.extract('( [0-9][0-9])')
# Out:
#        0
# 0    NaN
# 1     71
# 2    NaN
# 3     53
# 4    NaN
# ..   ...
# 886   13
# 887   30
# 888   23
# 889   30
# 890  NaN
#
# [891 rows x 1 columns]

# %%
ti['ticket'].sample(1)
# Out:
# 538    Ticket: Third; Price: $ 14.5; Port: Southampton;
# Name: ticket, dtype: object

# %%
ti['ticket'].str.extract('(Ticket: [A-Z])').sample(2)
# Out:
#              0
# 417  Ticket: S
# 526  Ticket: S

# %%
ti['ticket'].str.extract('(T........)').sample(3)
# Out:
#              0
# 552  Ticket: T
# 488  Ticket: T
# 836  Ticket: T

# %%
ti['ticket'].str.extract('(Price: [^0-9A-Za-z] ..)').sample(3)
# Out:
#                0
# 211  Price: $ 21
# 646  Price: $ 7.
# 866  Price: $ 13

# %%
ti['ticket'].str.extract('(Port: (Cherbourg|Southampton))').sample(3)
# Out:
#                      0            1
# 372  Port: Southampton  Southampton
# 44                 NaN          NaN
# 875    Port: Cherbourg    Cherbourg

# %%
ti['ticket'].str.extract('([0-9][0-9]?.[0-9]*)').sample(3)
# Out:
#           0
# 367  7.2292
# 348    15.9
# 583  40.125

# %%
ti['ticket'].str.extract('(Ticket: [a-zA-Z]+)').sample(3)
# Out:
#                   0
# 529  Ticket: Second
# 591   Ticket: First
# 814   Ticket: Third

# %%
row = 0
match = 1 # second match

ti['ticket'].str.extractall('([a-zA-Z]+: [a-zA-Z]+)').loc[row, match]
# Out:
# 0    Port: Southampton
# Name: (0, 1), dtype: object

# %%
ti['ticket'].str.extract('([a-zA-Z]+tow?n)')
# Out:
#                0
# 0    Southampton
# 1            NaN
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ..           ...
# 886  Southampton
# 887  Southampton
# 888  Southampton
# 889          NaN
# 890   Queenstown
#
# [891 rows x 1 columns]

# %%
ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)').sample(2)
# Out:
#             0
# 70     $ 10.5
# 444  $ 8.1125

# %%
ti['ticket'].str.extractall('([a-zA-Z]+: [a-zA-Z]+;$)').sample(1)
# Out:
#                             0
#     match
# 290 0      Port: Southampton;

# %%
ti['ticket'].str.extractall('(^[a-zA-Z]+: [a-zA-Z]+;)').sample(1)
# Out:
#                         0
#     match
# 840 0      Ticket: Third;

# %%
ti['ticket'].str.findall('([a-zA-Z]+[ :])').sample(10)
# Out:
# 126    [Ticket:, Price:, Port:]
# 568    [Ticket:, Price:, Port:]
# 163    [Ticket:, Price:, Port:]
# 179    [Ticket:, Price:, Port:]
# 737    [Ticket:, Price:, Port:]
# 540    [Ticket:, Price:, Port:]
# 93     [Ticket:, Price:, Port:]
# 246    [Ticket:, Price:, Port:]
# 262    [Ticket:, Price:, Port:]
# 112    [Ticket:, Price:, Port:]
# Name: ticket, dtype: object

# %%
ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)').sample(2)
# Out:
#              0
# 687  $ 10.1708
# 5     $ 8.4583

# %%
row = 0
match = 1 # second match
ti['ticket'].str.extractall('(\$ [0-9][0-9][0-9]+\.[0-9]+)')#.loc[row, 0]
# Out:
#                     0
#     match
# 27  0         $ 263.0
# 31  0      $ 146.5208
# 88  0         $ 263.0
# 118 0      $ 247.5208
# 195 0      $ 146.5208
# 215 0       $ 113.275
# 258 0      $ 512.3292
# 268 0      $ 153.4625
# 269 0      $ 135.6333
# 297 0        $ 151.55
# 299 0      $ 247.5208
# 305 0        $ 151.55
# 306 0      $ 110.8833
# 307 0         $ 108.9
# 311 0       $ 262.375
# 318 0      $ 164.8667
# 319 0         $ 134.5
# 325 0      $ 135.6333
# 332 0      $ 153.4625
# 334 0        $ 133.65
# 337 0         $ 134.5
# 341 0         $ 263.0
# 373 0      $ 135.6333
# 377 0         $ 211.5
# 380 0       $ 227.525
# 390 0         $ 120.0
# 393 0       $ 113.275
# 435 0         $ 120.0
# 438 0         $ 263.0
# 498 0        $ 151.55
# 505 0         $ 108.9
# 527 0      $ 221.7792
# 537 0       $ 106.425
# 544 0       $ 106.425
# 550 0      $ 110.8833
# 557 0       $ 227.525
# 581 0      $ 110.8833
# 609 0      $ 153.4625
# 659 0       $ 113.275
# 660 0        $ 133.65
# 679 0      $ 512.3292
# 689 0      $ 211.3375
# 698 0      $ 110.8833
# 700 0       $ 227.525
# 708 0        $ 151.55
# 716 0       $ 227.525
# 730 0      $ 211.3375
# 737 0      $ 512.3292
# 742 0       $ 262.375
# 763 0         $ 120.0
# 779 0      $ 211.3375
# 802 0         $ 120.0
# 856 0      $ 164.8667

# %% [markdown]
# # New Section
